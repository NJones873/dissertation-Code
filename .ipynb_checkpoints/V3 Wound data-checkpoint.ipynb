# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn import tree
import matplotlib.pyplot as plt
import re
import matplotlib
import numpy as np
import pandas as pd
import xgboost as xgb
from xgboost import plot_tree
import graphviz
from xgboost import XGBRegressor
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import random
from tensorflow.keras.utils import to_categorical
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.preprocessing import StandardScaler
from mlxtend.plotting import plot_decision_regions
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import pickle


Treatment=pd.read_csv("../dissertation/Wound data v3.csv")
df_x=Treatment.iloc[:,1:]
df_y=Treatment.iloc[:,0]
R_state=random.randrange(1,30)
R_state=17
print("Random_state: ",R_state)
X_train, X_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.2, random_state=R_state,stratify=df_y)

y_train_clf = to_categorical(y_train)
y_test_clf = to_categorical(y_test)

fullinfo=True
fulltree=True


def class1():
    clf=XGBClassifier(tree_method="hist",
                      subsample=0.6,
                      colsample_bynode=0.8,
                      colsample_bylevel=0.7,
                      reg_lambda=0.6,
                      reg_alpha=0.7,
                      max_bin=2056,
                      num_parallel_tree=15,
                      eta=0.03,

    )
    if fullinfo==True:
        clf.fit(X_train, y_train_clf)
        y_pred = clf.predict(X_test)
        y_pred = (y_pred > 0.5) 
        print(classification_report(y_test_clf,y_pred,output_dict=False,target_names=["healing","Not-healing"]))
        
        if fulltree==True:
            clf.fit(X_train, y_train)
            plt.figure(figsize=(400, 120))
            plot_tree(clf)
        accuracy = accuracy_score(y_test_clf, y_pred)
        print("Accuracy:", (accuracy*100),"%")
        print("------------------------------------------Classifier 1-------------------------------")
    return clf

def class2():
    clf=XGBClassifier(eta=0.01,
                      max_bin=1024,
    )
    if fullinfo==True:
        clf.fit(X_train, y_train_clf)
        y_pred = clf.predict(X_test)
        y_pred = (y_pred > 0.5) 
        print(classification_report(y_test_clf,y_pred,output_dict=False,target_names=["healing","Not-healing"]))
    
        if fulltree==True:
            clf.fit(X_train, y_train)
            plt.figure(figsize=(400, 120))
            plot_tree(clf)
        accuracy = accuracy_score(y_test_clf, y_pred)
        print("Accuracy:", (accuracy*100),"%")
        print("------------------------------------------Classifier 2-------------------------------")
    return clf

def class3():
    clf=XGBClassifier(tree_method="exact",
                  eta=0.02,
                  subsample=0.5,
                 
                   
                   max_bin=2056,
                    reg_alpha=0.8,
                 reg_lambda=0.8,
    )
    if fullinfo==True:
        clf.fit(X_train, y_train_clf)
        y_pred = clf.predict(X_test)
        y_pred = (y_pred > 0.5) 
        print(classification_report(y_test_clf,y_pred,output_dict=False,target_names=["healing","Not-healing"]))
    
        if fulltree==True:
            clf.fit(X_train, y_train)
            plt.figure(figsize=(400, 120))
            plot_tree(clf)
        accuracy = accuracy_score(y_test_clf, y_pred)
        print("Accuracy:", (accuracy*100),"%")
        print("------------------------------------------Classifier 3-------------------------------")
    return clf
    

    
def VoteClass():
    clf1=class1()
    clf2=class2()
    clf3=class3()
    sclf = VotingClassifier(estimators=[('clf1', clf1), ('clf2', clf2), ('clf3', clf3)],voting='soft',flatten_transform=False)
    
    sclf.fit(X_train, y_train)
    
    y_pred = sclf.predict(X_test)
    print(classification_report(np.asarray(y_test_clf).argmax(axis=1),y_pred,output_dict=False,target_names=["healing","Not-healing"]))
    
    accuracy = accuracy_score(np.asarray(y_test_clf).argmax(axis=1), y_pred)
    print("Accuracy:", (accuracy*100),"%")
    
    y_pred = sclf.predict_proba(X_test)
    print(y_pred)
    
    
    
   
VoteClass()
# Out:
# WARNING:tensorflow:From C:\Users\natej\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Random_state:  17
#               precision    recall  f1-score   support
#
#      healing       1.00      0.86      0.92         7
#  Not-healing       0.91      1.00      0.95        10
#
#    micro avg       0.94      0.94      0.94        17
#    macro avg       0.95      0.93      0.94        17
# weighted avg       0.95      0.94      0.94        17
#  samples avg       0.94      0.94      0.94        17
#
# Accuracy: 94.11764705882352 %
# ------------------------------------------Classifier 1-------------------------------
#               precision    recall  f1-score   support
#
#      healing       0.86      0.86      0.86         7
#  Not-healing       0.90      0.90      0.90        10
#
#    micro avg       0.88      0.88      0.88        17
#    macro avg       0.88      0.88      0.88        17
# weighted avg       0.88      0.88      0.88        17
#  samples avg       0.88      0.88      0.88        17
#
# Accuracy: 88.23529411764706 %
# ------------------------------------------Classifier 2-------------------------------
#               precision    recall  f1-score   support
#
#      healing       1.00      0.86      0.92         7
#  Not-healing       0.91      1.00      0.95        10
#
#    micro avg       0.94      0.94      0.94        17
#    macro avg       0.95      0.93      0.94        17
# weighted avg       0.95      0.94      0.94        17
#  samples avg       0.94      0.94      0.94        17
#
# Accuracy: 94.11764705882352 %
# ------------------------------------------Classifier 3-------------------------------
#               precision    recall  f1-score   support
#
#      healing       1.00      0.86      0.92         7
#  Not-healing       0.91      1.00      0.95        10
#
#     accuracy                           0.94        17
#    macro avg       0.95      0.93      0.94        17
# weighted avg       0.95      0.94      0.94        17
#
# Accuracy: 94.11764705882352 %
# [[0.32648143 0.6735186 ]
#  [0.31960526 0.6803947 ]
#  [0.30097267 0.6990273 ]
#  [0.67726207 0.32273796]
#  [0.315287   0.68471307]
#  [0.6589075  0.34109256]
#  [0.48447135 0.5155286 ]
#  [0.69868565 0.30131435]
#  [0.5190254  0.48097464]
#  [0.3206988  0.6793012 ]
#  [0.25079474 0.7492053 ]
#  [0.20988066 0.79011935]
#  [0.25112605 0.74887395]
#  [0.66557854 0.33442143]
#  [0.21874456 0.7812554 ]
#  [0.29994515 0.7000549 ]
#  [0.74110776 0.2588922 ]]
